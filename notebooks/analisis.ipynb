# %% [markdown]
# # DESARROLLO DEL ANÁLISIS TAREA 1. VIZUALIZACIÓN DE DATOS

# %%
from pathlib import Path
import pandas as pd


BASE_DIR = Path.cwd().parent  
DATA_DIR = BASE_DIR

df = pd.read_csv(DATA_DIR / "data" / "wfp_food_prices_col.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39263 entries, 0 to 39262
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          39263 non-null  object
#  1   admin1        39263 non-null  object
#  2   admin2        39263 non-null  object
#  3   market        39263 non-null  object
#  4   market_id     39263 non-null  int64
#  5   latitude      39263 non-null  float64
#  6   longitude     39263 non-null  float64
#  7   category      39263 non-null  object
#  8   commodity     39263 non-null  object
#  9   commodity_id  39263 non-null  int64
#  10  unit          39263 non-null  object
#  11  priceflag     39263 non-null  object
#  12  pricetype     39263 non-null  object
#  13  currency      39263 non-null  object
#  14  price         39263 non-null  float64
#  15  usdprice      39263 non-null  float64
# dtypes: float64(4), int64(2), object(10)
# memory usage: 4.8+ MB

# %%
df.sample(10)
# Out:
#              date              admin1  \
# 37844  2025-09-15              Caldas
# 10853  2020-08-15              Nariño
# 18368  2021-10-15               Cauca
# 38810  2025-11-15           Atlántico
# 31676  2023-12-15             Bolívar
# 3499   2012-09-15        Bogotá, D.c.
# 7626   2018-02-15        Bogotá, D.c.
# 35999  2024-08-15  Norte De Santander
# 21318  2022-04-15              Boyacá
# 21272  2022-04-15        Bogotá, D.c.
#
#                                                   admin2               market  \
# 37844                                          Manizales            Manizales
# 10853                                              Pasto                Pasto
# 18368                                            Bolívar              Popayan
# 38810  Distrito Especial, Industrial Y Portuario De B...         Barranquilla
# 31676                                Cartagena De Indias  Cartagena de Indias
# ...

# %%
df = pd.read_csv()
